# %%
import pandas as pd 
data = pd.read_csv(r"C:\Users\mariaedita.garcia\Desktop\data\proyecto5-casaslondres\london.csv")
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# Es importante siempre revisar los datos, y limpiar si hace falta.

# %%
#data.count()
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# 1) convierte el tipo de dato de 'fecha' a formato date-time

# %%
data.dtypes
# Out:
# date                 str
# area                 str
# average_price      int64
# code                 str
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.date = pd.to_datetime(data.date)
data.dtypes
# Out:
# date             datetime64[us]
# area                        str
# average_price             int64
# code                        str
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# 2.a) añade una nueva columna 'año' en los datos,  que solo tenga año

# %%
data['year'] = data.date.dt.year
data.head(5)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %% [markdown]
# 2.B)
